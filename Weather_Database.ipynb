# %%
#Import dependencies 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime
import requests
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #if the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
#print the city count to confirm sufficent count.
len(cities)
# Out:
# 619

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | easton
# Processing Record 5 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 1 | thompson
# Processing Record 7 of Set 1 | lata
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | hobyo
# Processing Record 11 of Set 1 | tiksi
# Processing Record 12 of Set 1 | leningradskiy
# Processing Record 13 of Set 1 | norman wells
# Processing Record 14 of Set 1 | castro
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | vila franca do campo
# Processing Record 17 of Set 1 | vestmannaeyjar
# Processing Record 18 of Set 1 | ojinaga
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | burica
# City not found. Skipping...
# Processing Record 21 of Set 1 | cherskiy
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | moron
# Processing Record 24 of Set 1 | barrow
# Processing Record 25 of Set 1 | acapulco
# Processing Record 26 of Set 1 | rocha
# Processing Record 27 of Set 1 | sembakung
# Processing Record 28 of Set 1 | zhuhai
# Processing Record 29 of Set 1 | port lincoln
# Processing Record 30 of Set 1 | arlit
# Processing Record 31 of Set 1 | sitka
# Processing Record 32 of Set 1 | georgetown
# Processing Record 33 of Set 1 | talnakh
# Processing Record 34 of Set 1 | gornyy
# Processing Record 35 of Set 1 | ayr
# Processing Record 36 of Set 1 | narsaq
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | tasiilaq
# Processing Record 39 of Set 1 | tuktoyaktuk
# Processing Record 40 of Set 1 | qaanaaq
# Processing Record 41 of Set 1 | mahanoro
# Processing Record 42 of Set 1 | porosozero
# Processing Record 43 of Set 1 | san buenaventura
# Processing Record 44 of Set 1 | charters towers
# Processing Record 45 of Set 1 | aldan
# Processing Record 46 of Set 1 | faya
# Processing Record 47 of Set 1 | hobart
# Processing Record 48 of Set 1 | vardo
# Processing Record 49 of Set 1 | bethel
# Processing Record 50 of Set 1 | zambezi
# Processing Record 1 of Set 2 | joshimath
# Processing Record 2 of Set 2 | saskylakh
# Processing Record 3 of Set 2 | amahai
# Processing Record 4 of Set 2 | basco
# Processing Record 5 of Set 2 | portlethen
# Processing Record 6 of Set 2 | nabire
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | jiaohe
# Processing Record 9 of Set 2 | strezhevoy
# Processing Record 10 of Set 2 | mar del plata
# Processing Record 11 of Set 2 | vanimo
# Processing Record 12 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | ferrol
# Processing Record 15 of Set 2 | morondava
# Processing Record 16 of Set 2 | bambous virieux
# Processing Record 17 of Set 2 | ponta do sol
# Processing Record 18 of Set 2 | tambopata
# Processing Record 19 of Set 2 | polysayevo
# Processing Record 20 of Set 2 | talcahuano
# Processing Record 21 of Set 2 | pevek
# Processing Record 22 of Set 2 | aasiaat
# Processing Record 23 of Set 2 | dikson
# Processing Record 24 of Set 2 | churapcha
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | grand gaube
# Processing Record 27 of Set 2 | port hedland
# Processing Record 28 of Set 2 | warri
# Processing Record 29 of Set 2 | bluff
# Processing Record 30 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | los llanos de aridane
# Processing Record 33 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 34 of Set 2 | dilla
# Processing Record 35 of Set 2 | dera bugti
# Processing Record 36 of Set 2 | ambon
# Processing Record 37 of Set 2 | fort nelson
# Processing Record 38 of Set 2 | ambovombe
# Processing Record 39 of Set 2 | tigwi
# City not found. Skipping...
# Processing Record 40 of Set 2 | lompoc
# Processing Record 41 of Set 2 | aska
# Processing Record 42 of Set 2 | kununurra
# Processing Record 43 of Set 2 | kavaratti
# Processing Record 44 of Set 2 | half moon bay
# Processing Record 45 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 2 | hasaki
# Processing Record 48 of Set 2 | salalah
# Processing Record 49 of Set 2 | saint-philippe
# Processing Record 50 of Set 2 | bengkulu
# Processing Record 1 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 3 | busselton
# Processing Record 3 of Set 3 | ribeira grande
# Processing Record 4 of Set 3 | meulaboh
# Processing Record 5 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 3 | bilibino
# Processing Record 7 of Set 3 | damghan
# Processing Record 8 of Set 3 | nouadhibou
# Processing Record 9 of Set 3 | asau
# Processing Record 10 of Set 3 | berbera
# Processing Record 11 of Set 3 | ercis
# Processing Record 12 of Set 3 | ndele
# Processing Record 13 of Set 3 | cape town
# Processing Record 14 of Set 3 | kommunarka
# Processing Record 15 of Set 3 | luderitz
# Processing Record 16 of Set 3 | chippewa falls
# Processing Record 17 of Set 3 | teahupoo
# Processing Record 18 of Set 3 | namatanai
# Processing Record 19 of Set 3 | mangit
# Processing Record 20 of Set 3 | lazaro cardenas
# Processing Record 21 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 3 | khandbari
# Processing Record 23 of Set 3 | narrabri
# Processing Record 24 of Set 3 | severo-kurilsk
# Processing Record 25 of Set 3 | saint george
# Processing Record 26 of Set 3 | ouadda
# Processing Record 27 of Set 3 | bredasdorp
# Processing Record 28 of Set 3 | kruisfontein
# Processing Record 29 of Set 3 | butaritari
# Processing Record 30 of Set 3 | smithers
# Processing Record 31 of Set 3 | le port
# Processing Record 32 of Set 3 | kapaa
# Processing Record 33 of Set 3 | guerrero negro
# Processing Record 34 of Set 3 | suntar
# Processing Record 35 of Set 3 | great yarmouth
# Processing Record 36 of Set 3 | rundu
# Processing Record 37 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 3 | karratha
# Processing Record 39 of Set 3 | ardalstangen
# Processing Record 40 of Set 3 | urubicha
# Processing Record 41 of Set 3 | sydney
# Processing Record 42 of Set 3 | okhotsk
# Processing Record 43 of Set 3 | san lazaro
# Processing Record 44 of Set 3 | mahebourg
# Processing Record 45 of Set 3 | haines junction
# Processing Record 46 of Set 3 | nador
# Processing Record 47 of Set 3 | mount gambier
# Processing Record 48 of Set 3 | russell
# Processing Record 49 of Set 3 | siderno
# Processing Record 50 of Set 3 | hellvik
# Processing Record 1 of Set 4 | santa fe
# Processing Record 2 of Set 4 | maitum
# Processing Record 3 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 4 | iqaluit
# Processing Record 5 of Set 4 | upernavik
# Processing Record 6 of Set 4 | kahului
# Processing Record 7 of Set 4 | the valley
# Processing Record 8 of Set 4 | atambua
# Processing Record 9 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 10 of Set 4 | umm lajj
# Processing Record 11 of Set 4 | aranos
# Processing Record 12 of Set 4 | souillac
# Processing Record 13 of Set 4 | maxixe
# Processing Record 14 of Set 4 | chokurdakh
# Processing Record 15 of Set 4 | kutum
# Processing Record 16 of Set 4 | bantogon
# Processing Record 17 of Set 4 | avarua
# Processing Record 18 of Set 4 | torrington
# Processing Record 19 of Set 4 | obluche
# City not found. Skipping...
# Processing Record 20 of Set 4 | cabo san lucas
# Processing Record 21 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 4 | hanko
# Processing Record 23 of Set 4 | paita
# Processing Record 24 of Set 4 | neustadt
# Processing Record 25 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 4 | urumqi
# Processing Record 27 of Set 4 | esperance
# Processing Record 28 of Set 4 | chuy
# Processing Record 29 of Set 4 | vaini
# Processing Record 30 of Set 4 | naze
# Processing Record 31 of Set 4 | lupsanu
# Processing Record 32 of Set 4 | manbij
# Processing Record 33 of Set 4 | hvide sande
# Processing Record 34 of Set 4 | coahuayana
# Processing Record 35 of Set 4 | my tho
# Processing Record 36 of Set 4 | telsiai
# Processing Record 37 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 39 of Set 4 | huarmey
# Processing Record 40 of Set 4 | saint-joseph
# Processing Record 41 of Set 4 | beyla
# Processing Record 42 of Set 4 | zachagansk
# City not found. Skipping...
# Processing Record 43 of Set 4 | ancud
# Processing Record 44 of Set 4 | kavieng
# Processing Record 45 of Set 4 | necochea
# Processing Record 46 of Set 4 | ambilobe
# Processing Record 47 of Set 4 | san quintin
# Processing Record 48 of Set 4 | faanui
# Processing Record 49 of Set 4 | parnarama
# Processing Record 50 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 5 | torbay
# Processing Record 2 of Set 5 | bogorodskoye
# Processing Record 3 of Set 5 | kaitangata
# Processing Record 4 of Set 5 | beringovskiy
# Processing Record 5 of Set 5 | nemuro
# Processing Record 6 of Set 5 | makakilo city
# Processing Record 7 of Set 5 | verkhnevilyuysk
# Processing Record 8 of Set 5 | college
# Processing Record 9 of Set 5 | melrose
# Processing Record 10 of Set 5 | pocoes
# Processing Record 11 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 12 of Set 5 | taoudenni
# Processing Record 13 of Set 5 | fairbanks
# Processing Record 14 of Set 5 | atikokan
# Processing Record 15 of Set 5 | kodiak
# Processing Record 16 of Set 5 | puksoozero
# Processing Record 17 of Set 5 | nikolskoye
# Processing Record 18 of Set 5 | victoria
# Processing Record 19 of Set 5 | puerto ayora
# Processing Record 20 of Set 5 | wajid
# Processing Record 21 of Set 5 | provideniya
# Processing Record 22 of Set 5 | itoman
# Processing Record 23 of Set 5 | alakurtti
# Processing Record 24 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 25 of Set 5 | lebu
# Processing Record 26 of Set 5 | cabedelo
# Processing Record 27 of Set 5 | kedrovyy
# Processing Record 28 of Set 5 | road town
# Processing Record 29 of Set 5 | ulaanbaatar
# Processing Record 30 of Set 5 | richards bay
# Processing Record 31 of Set 5 | huilong
# Processing Record 32 of Set 5 | inirida
# Processing Record 33 of Set 5 | hede
# Processing Record 34 of Set 5 | tambacounda
# Processing Record 35 of Set 5 | dalbandin
# Processing Record 36 of Set 5 | east london
# Processing Record 37 of Set 5 | adrar
# Processing Record 38 of Set 5 | sao luiz gonzaga
# Processing Record 39 of Set 5 | khatanga
# Processing Record 40 of Set 5 | kudymkar
# Processing Record 41 of Set 5 | asha
# Processing Record 42 of Set 5 | marsa matruh
# Processing Record 43 of Set 5 | gimli
# Processing Record 44 of Set 5 | ca mau
# Processing Record 45 of Set 5 | quatre cocos
# Processing Record 46 of Set 5 | itaituba
# Processing Record 47 of Set 5 | mackay
# Processing Record 48 of Set 5 | contai
# Processing Record 49 of Set 5 | new norfolk
# Processing Record 50 of Set 5 | glendive
# Processing Record 1 of Set 6 | concarneau
# Processing Record 2 of Set 6 | eyl
# Processing Record 3 of Set 6 | penha
# Processing Record 4 of Set 6 | bubaque
# Processing Record 5 of Set 6 | vaitape
# Processing Record 6 of Set 6 | grinnell
# Processing Record 7 of Set 6 | inuvik
# Processing Record 8 of Set 6 | lakes entrance
# Processing Record 9 of Set 6 | arraial do cabo
# Processing Record 10 of Set 6 | poso
# Processing Record 11 of Set 6 | carahue
# Processing Record 12 of Set 6 | meaux
# Processing Record 13 of Set 6 | kyzyl-suu
# Processing Record 14 of Set 6 | yelan
# Processing Record 15 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 16 of Set 6 | svetlaya
# Processing Record 17 of Set 6 | xinmin
# Processing Record 18 of Set 6 | la ronge
# Processing Record 19 of Set 6 | acarau
# Processing Record 20 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 6 | constitucion
# Processing Record 22 of Set 6 | marion
# Processing Record 23 of Set 6 | bonavista
# Processing Record 24 of Set 6 | ukiah
# Processing Record 25 of Set 6 | nanortalik
# Processing Record 26 of Set 6 | hervey bay
# Processing Record 27 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 28 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 6 | astoria
# Processing Record 30 of Set 6 | aklavik
# Processing Record 31 of Set 6 | santa maria
# Processing Record 32 of Set 6 | ati
# Processing Record 33 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 6 | touros
# Processing Record 35 of Set 6 | dingle
# Processing Record 36 of Set 6 | axim
# Processing Record 37 of Set 6 | lisakovsk
# Processing Record 38 of Set 6 | port blair
# Processing Record 39 of Set 6 | senanga
# Processing Record 40 of Set 6 | inyonga
# Processing Record 41 of Set 6 | alice springs
# Processing Record 42 of Set 6 | kviteseid
# Processing Record 43 of Set 6 | panalingaan
# Processing Record 44 of Set 6 | luganville
# Processing Record 45 of Set 6 | lavrentiya
# Processing Record 46 of Set 6 | maykain
# City not found. Skipping...
# Processing Record 47 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 6 | cartagena
# Processing Record 49 of Set 6 | olafsvik
# Processing Record 50 of Set 6 | kalmar
# Processing Record 1 of Set 7 | kidal
# Processing Record 2 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 3 of Set 7 | yuyao
# Processing Record 4 of Set 7 | buala
# Processing Record 5 of Set 7 | dalvik
# Processing Record 6 of Set 7 | clyde river
# Processing Record 7 of Set 7 | oranjemund
# Processing Record 8 of Set 7 | margate
# Processing Record 9 of Set 7 | north bend
# Processing Record 10 of Set 7 | kappeln
# Processing Record 11 of Set 7 | piacabucu
# Processing Record 12 of Set 7 | ola
# Processing Record 13 of Set 7 | mushie
# Processing Record 14 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 15 of Set 7 | borazjan
# Processing Record 16 of Set 7 | gbely
# Processing Record 17 of Set 7 | moa
# Processing Record 18 of Set 7 | nome
# Processing Record 19 of Set 7 | kirakira
# Processing Record 20 of Set 7 | amapa
# Processing Record 21 of Set 7 | akureyri
# Processing Record 22 of Set 7 | birao
# Processing Record 23 of Set 7 | sinnamary
# Processing Record 24 of Set 7 | tual
# Processing Record 25 of Set 7 | aguimes
# Processing Record 26 of Set 7 | yar-sale
# Processing Record 27 of Set 7 | nong chik
# Processing Record 28 of Set 7 | kokopo
# Processing Record 29 of Set 7 | ostrovnoy
# Processing Record 30 of Set 7 | balad
# Processing Record 31 of Set 7 | sao miguel do araguaia
# Processing Record 32 of Set 7 | fortuna
# Processing Record 33 of Set 7 | tallahassee
# Processing Record 34 of Set 7 | gualeguay
# Processing Record 35 of Set 7 | maltahohe
# Processing Record 36 of Set 7 | geraldton
# Processing Record 37 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 38 of Set 7 | port hardy
# Processing Record 39 of Set 7 | lodja
# Processing Record 40 of Set 7 | wladyslawowo
# Processing Record 41 of Set 7 | arman
# Processing Record 42 of Set 7 | nuuk
# Processing Record 43 of Set 7 | maua
# Processing Record 44 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 45 of Set 7 | hualmay
# Processing Record 46 of Set 7 | pangnirtung
# Processing Record 47 of Set 7 | umm durman
# City not found. Skipping...
# Processing Record 48 of Set 7 | klaksvik
# Processing Record 49 of Set 7 | ilulissat
# Processing Record 50 of Set 7 | sao filipe
# Processing Record 1 of Set 8 | flinders
# Processing Record 2 of Set 8 | hendijan
# City not found. Skipping...
# Processing Record 3 of Set 8 | general pico
# Processing Record 4 of Set 8 | port elizabeth
# Processing Record 5 of Set 8 | steinbach
# Processing Record 6 of Set 8 | burnie
# Processing Record 7 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 8 of Set 8 | hofn
# Processing Record 9 of Set 8 | tuatapere
# Processing Record 10 of Set 8 | cidreira
# Processing Record 11 of Set 8 | batticaloa
# Processing Record 12 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 8 | pandan
# Processing Record 14 of Set 8 | bintulu
# Processing Record 15 of Set 8 | dunedin
# Processing Record 16 of Set 8 | egvekinot
# Processing Record 17 of Set 8 | itatskiy
# Processing Record 18 of Set 8 | ust-nera
# Processing Record 19 of Set 8 | shimanovsk
# Processing Record 20 of Set 8 | esso
# Processing Record 21 of Set 8 | kanalia
# Processing Record 22 of Set 8 | wolgast
# Processing Record 23 of Set 8 | qaqortoq
# Processing Record 24 of Set 8 | lagoa
# Processing Record 25 of Set 8 | zyryanka
# Processing Record 26 of Set 8 | honningsvag
# Processing Record 27 of Set 8 | marquette
# Processing Record 28 of Set 8 | batagay-alyta
# Processing Record 29 of Set 8 | pacific grove
# Processing Record 30 of Set 8 | namangan
# Processing Record 31 of Set 8 | mareeba
# Processing Record 32 of Set 8 | bereda
# Processing Record 33 of Set 8 | cruzeiro do sul
# Processing Record 34 of Set 8 | dhidhdhoo
# Processing Record 35 of Set 8 | vestmanna
# Processing Record 36 of Set 8 | mnogovershinnyy
# Processing Record 37 of Set 8 | pasinler
# Processing Record 38 of Set 8 | beisfjord
# Processing Record 39 of Set 8 | ketchikan
# Processing Record 40 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 41 of Set 8 | northam
# Processing Record 42 of Set 8 | miles city
# Processing Record 43 of Set 8 | grand-santi
# Processing Record 44 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 8 | rudnya
# Processing Record 46 of Set 8 | aksu
# Processing Record 47 of Set 8 | broome
# Processing Record 48 of Set 8 | lincoln
# Processing Record 49 of Set 8 | jinchang
# Processing Record 50 of Set 8 | christchurch
# Processing Record 1 of Set 9 | honiara
# Processing Record 2 of Set 9 | pacifica
# Processing Record 3 of Set 9 | goma
# Processing Record 4 of Set 9 | aykhal
# Processing Record 5 of Set 9 | kalmunai
# Processing Record 6 of Set 9 | saint-augustin
# Processing Record 7 of Set 9 | baykit
# Processing Record 8 of Set 9 | khuzhir
# Processing Record 9 of Set 9 | tromso
# Processing Record 10 of Set 9 | samagaltay
# Processing Record 11 of Set 9 | westport
# Processing Record 12 of Set 9 | benguela
# Processing Record 13 of Set 9 | vengerovo
# Processing Record 14 of Set 9 | dandong
# Processing Record 15 of Set 9 | elizabeth city
# Processing Record 16 of Set 9 | khirkiya
# Processing Record 17 of Set 9 | zhangye
# Processing Record 18 of Set 9 | dharchula
# Processing Record 19 of Set 9 | colares
# Processing Record 20 of Set 9 | skelleftea
# Processing Record 21 of Set 9 | palana
# Processing Record 22 of Set 9 | lorengau
# Processing Record 23 of Set 9 | tabarqah
# City not found. Skipping...
# Processing Record 24 of Set 9 | porterville
# Processing Record 25 of Set 9 | parrita
# Processing Record 26 of Set 9 | raudeberg
# Processing Record 27 of Set 9 | araouane
# Processing Record 28 of Set 9 | bataipora
# Processing Record 29 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 9 | hauterive
# Processing Record 31 of Set 9 | saldanha
# Processing Record 32 of Set 9 | nancha
# Processing Record 33 of Set 9 | nelson bay
# Processing Record 34 of Set 9 | whitehorse
# Processing Record 35 of Set 9 | padang
# Processing Record 36 of Set 9 | phrae
# Processing Record 37 of Set 9 | durham
# Processing Record 38 of Set 9 | urambo
# Processing Record 39 of Set 9 | cadillac
# Processing Record 40 of Set 9 | maragogi
# Processing Record 41 of Set 9 | ayabe
# Processing Record 42 of Set 9 | pokosnoye
# Processing Record 43 of Set 9 | yulara
# Processing Record 44 of Set 9 | gander
# Processing Record 45 of Set 9 | udachnyy
# Processing Record 46 of Set 9 | santa isabel
# Processing Record 47 of Set 9 | paracuru
# Processing Record 48 of Set 9 | pangody
# Processing Record 49 of Set 9 | sao joao da barra
# Processing Record 50 of Set 9 | gat
# Processing Record 1 of Set 10 | grado
# Processing Record 2 of Set 10 | belaya kholunitsa
# Processing Record 3 of Set 10 | santa maria del oro
# Processing Record 4 of Set 10 | kudahuvadhoo
# Processing Record 5 of Set 10 | katherine
# Processing Record 6 of Set 10 | norsup
# Processing Record 7 of Set 10 | dubrovka
# Processing Record 8 of Set 10 | kropotkin
# Processing Record 9 of Set 10 | marathon
# Processing Record 10 of Set 10 | laguna
# Processing Record 11 of Set 10 | wufeng
# Processing Record 12 of Set 10 | koungou
# Processing Record 13 of Set 10 | manchester
# Processing Record 14 of Set 10 | santa marta
# Processing Record 15 of Set 10 | husavik
# Processing Record 16 of Set 10 | bar harbor
# Processing Record 17 of Set 10 | kiunga
# Processing Record 18 of Set 10 | chingirlau
# Processing Record 19 of Set 10 | pontianak
# Processing Record 20 of Set 10 | sabzevar
# Processing Record 21 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 22 of Set 10 | mucurici
# Processing Record 23 of Set 10 | anuradhapura
# Processing Record 24 of Set 10 | tsirguliina
# Processing Record 25 of Set 10 | cayenne
# Processing Record 26 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 27 of Set 10 | batagay
# Processing Record 28 of Set 10 | kismayo
# Processing Record 29 of Set 10 | abu samrah
# Processing Record 30 of Set 10 | arvika
# Processing Record 31 of Set 10 | navalmoral de la mata
# Processing Record 32 of Set 10 | povoa de santa iria
# Processing Record 33 of Set 10 | padilla
# Processing Record 34 of Set 10 | marzuq
# Processing Record 35 of Set 10 | vao
# Processing Record 36 of Set 10 | waingapu
# Processing Record 37 of Set 10 | kloulklubed
# Processing Record 38 of Set 10 | isangel
# Processing Record 39 of Set 10 | alyangula
# Processing Record 40 of Set 10 | paragominas
# Processing Record 41 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 42 of Set 10 | yamada
# Processing Record 43 of Set 10 | kungurtug
# Processing Record 44 of Set 10 | maputo
# Processing Record 45 of Set 10 | te anau
# Processing Record 46 of Set 10 | inhambane
# Processing Record 47 of Set 10 | nara
# Processing Record 48 of Set 10 | morant bay
# Processing Record 49 of Set 10 | eureka
# Processing Record 50 of Set 10 | coquimbo
# Processing Record 1 of Set 11 | sterling
# Processing Record 2 of Set 11 | fengxian
# Processing Record 3 of Set 11 | itarema
# Processing Record 4 of Set 11 | carnduff
# Processing Record 5 of Set 11 | saint-pierre
# Processing Record 6 of Set 11 | fukue
# Processing Record 7 of Set 11 | comodoro rivadavia
# Processing Record 8 of Set 11 | zemio
# Processing Record 9 of Set 11 | tilichiki
# Processing Record 10 of Set 11 | brae
# Processing Record 11 of Set 11 | ziro
# Processing Record 12 of Set 11 | ellensburg
# Processing Record 13 of Set 11 | codrington
# Processing Record 14 of Set 11 | lufilufi
# Processing Record 15 of Set 11 | embonas
# Processing Record 16 of Set 11 | mayor pablo lagerenza
# Processing Record 17 of Set 11 | dubbo
# Processing Record 18 of Set 11 | falun
# Processing Record 19 of Set 11 | hambantota
# Processing Record 20 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 21 of Set 11 | port hawkesbury
# Processing Record 22 of Set 11 | ugoofaaru
# Processing Record 23 of Set 11 | burgeo
# Processing Record 24 of Set 11 | aquiraz
# Processing Record 25 of Set 11 | morgan city
# Processing Record 26 of Set 11 | katobu
# Processing Record 27 of Set 11 | campbell river
# Processing Record 28 of Set 11 | seoul
# Processing Record 29 of Set 11 | malko tarnovo
# Processing Record 30 of Set 11 | emerald
# Processing Record 31 of Set 11 | granville
# Processing Record 32 of Set 11 | gazalkent
# Processing Record 33 of Set 11 | maceio
# Processing Record 34 of Set 11 | bonito
# Processing Record 35 of Set 11 | vostok
# Processing Record 36 of Set 11 | killybegs
# Processing Record 37 of Set 11 | alghero
# Processing Record 38 of Set 11 | isla mujeres
# Processing Record 39 of Set 11 | ust-koksa
# Processing Record 40 of Set 11 | kapoeta
# Processing Record 41 of Set 11 | pryazha
# Processing Record 42 of Set 11 | selishche
# Processing Record 43 of Set 11 | cacoal
# Processing Record 44 of Set 11 | qianan
# Processing Record 45 of Set 11 | sisimiut
# Processing Record 46 of Set 11 | komsomolskiy
# Processing Record 47 of Set 11 | batsfjord
# Processing Record 48 of Set 11 | coracao de jesus
# Processing Record 49 of Set 11 | wenzhou
# Processing Record 50 of Set 11 | vallenar
# Processing Record 1 of Set 12 | adre
# Processing Record 2 of Set 12 | asosa
# Processing Record 3 of Set 12 | muncar
# Processing Record 4 of Set 12 | antananarivo
# Processing Record 5 of Set 12 | dwarka
# Processing Record 6 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 7 of Set 12 | grande-synthe
# Processing Record 8 of Set 12 | changli
# Processing Record 9 of Set 12 | poum
# Processing Record 10 of Set 12 | westerland
# Processing Record 11 of Set 12 | kangaba
# Processing Record 12 of Set 12 | sabha
# Processing Record 13 of Set 12 | katsuura
# Processing Record 14 of Set 12 | kisangani
# Processing Record 15 of Set 12 | sambava
# Processing Record 16 of Set 12 | galegos
# Processing Record 17 of Set 12 | ardakan
# Processing Record 18 of Set 12 | braganca
# Processing Record 19 of Set 12 | himora
# City not found. Skipping...
# Processing Record 20 of Set 12 | gravdal
# Processing Record 21 of Set 12 | airai
# Processing Record 22 of Set 12 | barra patuca
# Processing Record 23 of Set 12 | bathsheba
# Processing Record 24 of Set 12 | kusti
# Processing Record 25 of Set 12 | bima
# Processing Record 26 of Set 12 | sabya
# Processing Record 27 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 28 of Set 12 | verkh-usugli
# Processing Record 29 of Set 12 | kongolo
# Processing Record 30 of Set 12 | vila velha
# Processing Record 31 of Set 12 | bayevo
# Processing Record 32 of Set 12 | sioux lookout
# Processing Record 33 of Set 12 | shatrovo
# Processing Record 34 of Set 12 | cape elizabeth
# City not found. Skipping...
# Processing Record 35 of Set 12 | san patricio
# Processing Record 36 of Set 12 | rensvik
# Processing Record 37 of Set 12 | palmer
# Processing Record 38 of Set 12 | sibay
# Processing Record 39 of Set 12 | jumla
# Processing Record 40 of Set 12 | alexandria
# Processing Record 41 of Set 12 | xam nua
# Processing Record 42 of Set 12 | cururupu
# Processing Record 43 of Set 12 | fare
# Processing Record 44 of Set 12 | ballina
# Processing Record 45 of Set 12 | omsukchan
# Processing Record 46 of Set 12 | phalodi
# Processing Record 47 of Set 12 | hamilton
# Processing Record 48 of Set 12 | rio gallegos
# Processing Record 49 of Set 12 | asyut
# Processing Record 50 of Set 12 | salvador
# Processing Record 1 of Set 13 | smoky lake
# Processing Record 2 of Set 13 | muscat
# Processing Record 3 of Set 13 | kananga
# Processing Record 4 of Set 13 | krasnokamensk
# Processing Record 5 of Set 13 | codajas
# Processing Record 6 of Set 13 | orange cove
# Processing Record 7 of Set 13 | prainha
# Processing Record 8 of Set 13 | araguaina
# Processing Record 9 of Set 13 | gazanjyk
# Processing Record 10 of Set 13 | manicore
# Processing Record 11 of Set 13 | urengoy
# Processing Record 12 of Set 13 | avera
# Processing Record 13 of Set 13 | dauriya
# Processing Record 14 of Set 13 | sur
# Processing Record 15 of Set 13 | praia da vitoria
# Processing Record 16 of Set 13 | tommot
# Processing Record 17 of Set 13 | aras
# Processing Record 18 of Set 13 | paamiut
# Processing Record 19 of Set 13 | ahipara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Albany      US  42.6001  -73.9662     63.41        86
# 1             Rikitea      PF -23.1203 -134.9692     74.84        75
# 2         Port Alfred      ZA -33.5906   26.8910     60.13        59
# 3              Easton      US  40.6884  -75.2207     75.54        81
# 4            Thompson      CA  55.7435  -97.8558     55.78        72
# ..                ...     ...      ...       ...       ...       ...
# 564  Praia Da Vitoria      PT  38.7333  -27.0667     64.65        88
# 565            Tommot      RU  58.9564  126.2925     75.09        68
# 566              Aras      ES  42.5617   -2.3560     54.01        88
# 567           Paamiut      GL  61.9940  -49.6678     41.45        95
# 568           Ahipara      NZ -35.1667  173.1667     61.57        98
#
#      Cloudiness  Wind Speed Current Description
# 0            18        3.74          few clouds
# 1            50       20.51    scattered clouds
# 2             0        9.60           clear sky
# 3           100        3.44     overcast clouds
# 4            80        5.93       broken clouds
# ..          ...         ...                 ...
# 564          75       10.58       broken clouds
# 565          97       13.56          light rain
# 566          20       12.66          few clouds
# 567         100        4.38     overcast clouds
# 568         100        9.80          light rain
#
# [569 rows x 9 columns]

# %%
city_data_df.to_csv("Weather_Database/WeatherPy_Database.csv")
